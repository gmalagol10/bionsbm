# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt

import os
import json
import string

from matplotlib.ticker import FormatStrFormatter
from sklearn.metrics import adjusted_mutual_info_score as AMI
from matplotlib.patches import Patch
colors_to_use_pastel=[(0.5665516830630946, 0.5037138904751852, 0.5075215212500083),
 (0.9949012052279167, 0.7553237006975844, 0.5055095027008268),
 (0.6013710840316495, 0.6764106146805113, 0.9895579386673582),
 (0.998816092724718, 0.7071878014442006, 0.8979090191443285),
 (0.5429870427410571, 0.750719571440085, 0.6124765491924715),
 (0.5084695919264852, 0.5093366344721296, 0.9990436978593071),
 (0.8246194014837736, 0.9846839170837028, 0.5089892119497516),
 (0.5052972476002842, 0.5444186786858283, 0.7812964942323839),
 (0.5124601533942488, 0.9750384643760528, 0.9697621879182152),
 (0.9728598314959997, 0.5013134514042519, 0.8469604310077152)]

# %% [markdown]
# # SuppFig1

# %% [markdown]
# ## Data

# %%
metadata=pd.DataFrame()
shapes={}
for file in sorted(glob.glob("Datasets/*/CM/*GEX_Raw.h5ad")):
    if "Neuroblastoma" not in file:
        adata=sc.read_h5ad(file)
        obs=pd.DataFrame(adata.obs["CellType"])
        dataset=file.split("/")[1]
        obs["Dataset"]=dataset
        shapes[dataset]=adata.shape
        metadata=pd.concat([metadata, obs])

# %%
with open('Tables/shapes.json', 'w') as f:
    json.dump(shapes, f)
metadata.to_csv("Tables/Metadata.tsv.gz", sep="\t", compression="gzip")

# %%
data=pd.DataFrame(columns=["Dataset","Omic","Size"])
for omic in ["Peak","ADT","mRNA","lncRNA","GEX"]:
    if "Neuroblastoma" not in file:
        print(omic)
        files=sorted(glob.glob(f"Datasets/*/CM/*{omic}_Raw.h5ad"))
        for file in files:
            print(file)
            adata=sc.read_h5ad(file)
            ds=file.split("/")[1]
            d=pd.DataFrame([ds, omic, adata.shape[1]], index=data.columns).T
            data=pd.concat([data,d])
data=data[data["Dataset"]!="Neuroblastoma"]
data
# Out:
# Peak
# Datasets/BMMCMultiOme/CM/BMMCMultiOme_Peak_Raw.h5ad
# Datasets/HSPC/CM/HSPC_Peak_Raw.h5ad
# Datasets/MouseSkin/CM/MouseSkin_Peak_Raw.h5ad
# Datasets/Neuroblastoma/CM/Neuroblastoma_Peak_Raw.h5ad
# Datasets/PBMC/CM/PBMC_Peak_Raw.h5ad
# ADT
# Datasets/BMMCCite/CM/BMMCCite_ADT_Raw.h5ad
# Datasets/Spleen/CM/Spleen_ADT_Raw.h5ad
# mRNA
# Datasets/BMMCCite/CM/BMMCCite_mRNA_Raw.h5ad
# Datasets/BMMCMultiOme/CM/BMMCMultiOme_mRNA_Raw.h5ad
# Datasets/HSPC/CM/HSPC_mRNA_Raw.h5ad
# Datasets/MouseSkin/CM/MouseSkin_mRNA_Raw.h5ad
# Datasets/Neuroblastoma/CM/Neuroblastoma_mRNA_Raw.h5ad
# Datasets/PBMC/CM/PBMC_mRNA_Raw.h5ad
# Datasets/Spleen/CM/Spleen_mRNA_Raw.h5ad
# lncRNA
# Datasets/BMMCCite/CM/BMMCCite_lncRNA_Raw.h5ad
# Datasets/BMMCMultiOme/CM/BMMCMultiOme_lncRNA_Raw.h5ad
# Datasets/HSPC/CM/HSPC_lncRNA_Raw.h5ad
# Datasets/MouseSkin/CM/MouseSkin_lncRNA_Raw.h5ad
# Datasets/Neuroblastoma/CM/Neuroblastoma_lncRNA_Raw.h5ad
# Datasets/PBMC/CM/PBMC_lncRNA_Raw.h5ad
# Datasets/Spleen/CM/Spleen_lncRNA_Raw.h5ad
# GEX
# Datasets/BMMCCite/CM/BMMCCite_GEX_Raw.h5ad
# Datasets/BMMCMultiOme/CM/BMMCMultiOme_GEX_Raw.h5ad
# Datasets/HSPC/CM/HSPC_GEX_Raw.h5ad
# Datasets/MouseSkin/CM/MouseSkin_GEX_Raw.h5ad
# Datasets/Neuroblastoma/CM/Neuroblastoma_GEX_Raw.h5ad
# Datasets/PBMC/CM/PBMC_GEX_Raw.h5ad
# Datasets/Spleen/CM/Spleen_GEX_Raw.h5ad
#         Dataset    Omic    Size
# 0  BMMCMultiOme    Peak  116468
# 0          HSPC    Peak  226005
# 0     MouseSkin    Peak  344592
# 0          PBMC    Peak  129625
# 0      BMMCCite     ADT     134
# 0        Spleen     ADT     209
# 0      BMMCCite    mRNA   11700
# 0  BMMCMultiOme    mRNA    4658
# 0          HSPC    mRNA   18782
# 0     MouseSkin    mRNA   17106
# 0          PBMC    mRNA    9056
# 0        Spleen    mRNA   11554
# 0      BMMCCite  lncRNA     686
# 0  BMMCMultiOme  lncRNA     598
# 0          HSPC  lncRNA    3988
# 0     MouseSkin  lncRNA    3868
# 0          PBMC  lncRNA    5573
# 0        Spleen  lncRNA     894
# 0      BMMCCite     GEX   13953
# 0  BMMCMultiOme     GEX   13431
# 0          HSPC     GEX   36601
# 0     MouseSkin     GEX   23296
# 0          PBMC     GEX   43925
# 0        Spleen     GEX   13553

# %%
data.to_csv("Tables/Metadata_features_size.tsv.gz", sep="\t", compression="gzip")

# %% [markdown]
# ## Figure

# %%
metadata=pd.read_csv("Tables/Metadata.tsv.gz", sep="\t", index_col=0)
data=pd.read_csv("Tables/Metadata_features_size.tsv.gz", sep="\t", index_col=0)
with open('Tables/shapes.json') as f:
    shapes = json.load(f)
cts={}
for ds in sorted(set(metadata["Dataset"])):
    d=metadata[metadata["Dataset"]==ds]
    cts[ds]=len(set(d["CellType"]))
mains=data[(data["Omic"]=="Peak") ^ (data["Omic"]=="ADT")][["Dataset","Size"]].set_index("Dataset").to_dict()["Size"]
gexs=data[data["Omic"]=="GEX"][["Dataset","Size"]].set_index("Dataset").to_dict()["Size"]
mrnas=data[data["Omic"]=="mRNA"][["Dataset","Size"]].set_index("Dataset").to_dict()["Size"]
lncrnas=data[data["Omic"]=="lncRNA"][["Dataset","Size"]].set_index("Dataset").to_dict()["Size"]

# %%
fig, axs = plt.subplots(1,3, dpi=300, figsize=(15,5))
axs=axs.flatten()

x=np.log10(np.array(list(shapes.values())).T[0])
y=[cts[key] for key in shapes.keys()]
axs[0].scatter(x=x, y=y)
for i, label in enumerate(shapes.keys()):
    axs[0].annotate(
        label, 
        (x[i], y[i]),              # point position
        textcoords="offset points", 
        xytext=(-7,5),              # offset text position
        ha='left', fontsize=8,
        arrowprops=dict(arrowstyle="->", color="gray", lw=0.5))
axs[0].set_xlabel("Number of cells [log10(count)]", size=13)
axs[0].set_ylabel("Number of cell types [count]", size=13)

x=np.log10(list(gexs.values()))
y=np.log10([mains[key] for key in gexs.keys()])
axs[1].scatter(x=x, y=y)
for i, label in enumerate(gexs.keys()):
    axs[1].annotate(
        label, 
        (x[i], y[i]),              # point position
        textcoords="offset points", 
        xytext=(-7,5),              # offset text position
        ha='left', fontsize=8,
        arrowprops=dict(arrowstyle="->", color="gray", lw=0.5))
axs[1].set_xlabel("Number of genes [log10(count)]", size=13)
axs[1].set_ylabel("Number of peaks or\nsurface proteins [log10(count)]", size=13)

x=np.log10(list(mrnas.values()))
y=np.log10([lncrnas[key] for key in mrnas.keys()])
axs[2].scatter(x=x, y=y)
for i, label in enumerate(mrnas.keys()):
    axs[2].annotate(
        label, 
        (x[i], y[i]),              # point position
        textcoords="offset points", 
        xytext=(-7,5),              # offset text position
        ha='left', fontsize=8,
        arrowprops=dict(arrowstyle="->", color="gray", lw=0.5))
axs[2].set_xlabel("Number of mRNAs [log10(count)]", size=13)
axs[2].set_ylabel("Number of lncRNAs [log10(count)]", size=13)

for i, ax in enumerate(axs):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.text(-0.075, 1.05, string.ascii_uppercase[i], transform=ax.transAxes, size=20, weight='bold',rotation=0)  

plt.tight_layout(w_pad=1.5)
plt.savefig("Figures/SuppFig1.png", format="png", dpi=300, bbox_inches='tight')
plt.show()
